# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurLimaMoura/ProjetoExtensao_Python-Pandas/blob/main/De%2006%20/02%20a%2010/02%20Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primeiro exemplo de manipulção usando o python pandas.
# Por, Arthur,
# 06/02/2023 a 08/02/2023

# %%
import pandas as pd

combustiveis_df = pd.read_excel("ca-2021-02.xlsx")

# %%
print(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 4                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...                                            ...                  ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA   28.629.089/0001-79
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
#
#                                       Nome da Rua Numero Rua Complemento  \
# 0                                  RODOVIA AL 220        105       KM 68
# 1                                  RODOVIA AL 220        105       KM 68
# 2                                  RODOVIA AL 220        105       KM 68
# 3                                  RODOVIA AL 220        105       KM 68
# 4                                  RODOVIA AL 220        105       KM 68
# ...                                           ...        ...         ...
# 168404                  AVENIDA T LOT JD TROPICAL         53         NaN
# 168405  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
# 168406  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
# 168407  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
# 168408  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
#
#              Bairro        Cep             Produto Data da Coleta  \
# 0       CANAFISTULA  57302-605            GASOLINA     2021-11-01
# 1       CANAFISTULA  57302-605              ETANOL     2021-11-01
# 2       CANAFISTULA  57302-605              DIESEL     2021-11-01
# 3       CANAFISTULA  57302-605  GASOLINA ADITIVADA     2021-11-01
# 4       CANAFISTULA  57302-605          DIESEL S10     2021-11-01
# ...             ...        ...                 ...            ...
# 168404     TROPICAL  45209-130              ETANOL     2021-12-31
# 168405     ALVORADA  38307-113            GASOLINA     2021-12-31
# 168406     ALVORADA  38307-113              ETANOL     2021-12-31
# 168407     ALVORADA  38307-113          DIESEL S10     2021-12-31
# 168408     ALVORADA  38307-113  GASOLINA ADITIVADA     2021-12-31
#
#         Valor de Venda  Valor de Compra Unidade de Medida       Bandeira
# 0                6.799              NaN        R$ / litro  VIBRA ENERGIA
# 1                5.299              NaN        R$ / litro  VIBRA ENERGIA
# 2                5.549              NaN        R$ / litro  VIBRA ENERGIA
# 3                6.899              NaN        R$ / litro  VIBRA ENERGIA
# 4                5.649              NaN        R$ / litro  VIBRA ENERGIA
# ...                ...              ...               ...            ...
# 168404           5.859              NaN        R$ / litro     PETROSERRA
# 168405           6.580              NaN        R$ / litro         BRANCA
# 168406           4.740              NaN        R$ / litro         BRANCA
# 168407           5.448              NaN        R$ / litro         BRANCA
# 168408           6.580              NaN        R$ / litro         BRANCA
#
# [168409 rows x 16 columns]

# %%
display(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 4                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...                                            ...                  ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA   28.629.089/0001-79
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA   13.117.591/0006-38
#
#                                       Nome da Rua Numero Rua Complemento  \
# 0                                  RODOVIA AL 220        105       KM 68
# 1                                  RODOVIA AL 220        105       KM 68
# 2                                  RODOVIA AL 220        105       KM 68
# 3                                  RODOVIA AL 220        105       KM 68
# 4                                  RODOVIA AL 220        105       KM 68
# ...                                           ...        ...         ...
# 168404                  AVENIDA T LOT JD TROPICAL         53         NaN
# 168405  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
# 168406  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
# 168407  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
# 168408  AVENIDA PROFESSOR JOSE VIEIRA DE MENDONCA       2415         NaN
#
#              Bairro        Cep             Produto Data da Coleta  \
# 0       CANAFISTULA  57302-605            GASOLINA     2021-11-01
# 1       CANAFISTULA  57302-605              ETANOL     2021-11-01
# 2       CANAFISTULA  57302-605              DIESEL     2021-11-01
# 3       CANAFISTULA  57302-605  GASOLINA ADITIVADA     2021-11-01
# 4       CANAFISTULA  57302-605          DIESEL S10     2021-11-01
# ...             ...        ...                 ...            ...
# 168404     TROPICAL  45209-130              ETANOL     2021-12-31
# 168405     ALVORADA  38307-113            GASOLINA     2021-12-31
# 168406     ALVORADA  38307-113              ETANOL     2021-12-31
# 168407     ALVORADA  38307-113          DIESEL S10     2021-12-31
# 168408     ALVORADA  38307-113  GASOLINA ADITIVADA     2021-12-31
#
#         Valor de Venda  Valor de Compra Unidade de Medida       Bandeira
# 0                6.799              NaN        R$ / litro  VIBRA ENERGIA
# 1                5.299              NaN        R$ / litro  VIBRA ENERGIA
# 2                5.549              NaN        R$ / litro  VIBRA ENERGIA
# 3                6.899              NaN        R$ / litro  VIBRA ENERGIA
# 4                5.649              NaN        R$ / litro  VIBRA ENERGIA
# ...                ...              ...               ...            ...
# 168404           5.859              NaN        R$ / litro     PETROSERRA
# 168405           6.580              NaN        R$ / litro         BRANCA
# 168406           4.740              NaN        R$ / litro         BRANCA
# 168407           5.448              NaN        R$ / litro         BRANCA
# 168408           6.580              NaN        R$ / litro         BRANCA
#
# [168409 rows x 16 columns]

# %%
#Exibe as primeiras 5 linhas
display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira
# 0              NaN        R$ / litro  VIBRA ENERGIA
# 1              NaN        R$ / litro  VIBRA ENERGIA
# 2              NaN        R$ / litro  VIBRA ENERGIA
# 3              NaN        R$ / litro  VIBRA ENERGIA
# 4              NaN        R$ / litro  VIBRA ENERGIA

# %%
from pandas.core.generic import com
#Quero exiber as primeireas 15 linhas
display(combustiveis_df.head(15))
# Out:
#    Regiao - Sigla Estado - Sigla        Municipio  \
# 0              NE             AL        ARAPIRACA
# 1              NE             AL        ARAPIRACA
# 2              NE             AL        ARAPIRACA
# 3              NE             AL        ARAPIRACA
# 4              NE             AL        ARAPIRACA
# 5              NE             AL  DELMIRO GOUVEIA
# 6              NE             AL  DELMIRO GOUVEIA
# 7              NE             AL  DELMIRO GOUVEIA
# 8              NE             AL  DELMIRO GOUVEIA
# 9              NE             AL  DELMIRO GOUVEIA
# 10             NE             AL  DELMIRO GOUVEIA
# 11             NE             AL  DELMIRO GOUVEIA
# 12             NE             AL  DELMIRO GOUVEIA
# 13             NE             AL  DELMIRO GOUVEIA
# 14             NE             AL  DELMIRO GOUVEIA
#
#                                   Revenda      CNPJ da Revenda  \
# 0                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 4                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 5          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 6          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 7          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 8          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 9          AUTO POSTO FREITAS & MAIA LTDA   12.436.978/0001-80
# 10               AUTO POSTO DA PEDRA LTDA   05.518.639/0001-87
# 11               AUTO POSTO DA PEDRA LTDA   05.518.639/0001-87
# 12               AUTO POSTO DA PEDRA LTDA   05.518.639/0001-87
# 13               AUTO POSTO DA PEDRA LTDA   05.518.639/0001-87
# 14  COMERCIO DE COMBUSTIVEIS NENZITA LTDA   04.431.113/0001-00
#
#              Nome da Rua Numero Rua Complemento       Bairro        Cep  \
# 0         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 1         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 2         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 3         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 4         RODOVIA AL 220        105       KM 68  CANAFISTULA  57302-605
# 5   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 6   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 7   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 8   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 9   RUA FLORIANO PEIXOTO        247         NaN       CENTRO  57480-000
# 10  RUA FLORIANO PEIXOTO        281         NaN       CENTRO  57480-000
# 11  RUA FLORIANO PEIXOTO        281         NaN       CENTRO  57480-000
# 12  RUA FLORIANO PEIXOTO        281         NaN       CENTRO  57480-000
# 13  RUA FLORIANO PEIXOTO        281         NaN       CENTRO  57480-000
# 14       AVENIDA CAXANGA        126         NaN  PEDRA VELHA  57480-000
#
#                Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0             GASOLINA     2021-11-01           6.799              NaN
# 1               ETANOL     2021-11-01           5.299              NaN
# 2               DIESEL     2021-11-01           5.549              NaN
# 3   GASOLINA ADITIVADA     2021-11-01           6.899              NaN
# 4           DIESEL S10     2021-11-01           5.649              NaN
# 5             GASOLINA     2021-11-01           7.198              NaN
# 6               ETANOL     2021-11-01           5.982              NaN
# 7               DIESEL     2021-11-01           5.974              NaN
# 8   GASOLINA ADITIVADA     2021-11-01           7.208              NaN
# 9           DIESEL S10     2021-11-01           5.983              NaN
# 10            GASOLINA     2021-11-01           7.197              NaN
# 11              ETANOL     2021-11-01           5.987              NaN
# 12              DIESEL     2021-11-01           5.978              NaN
# 13          DIESEL S10     2021-11-01           5.989              NaN
# 14            GASOLINA     2021-11-01           7.175              NaN
#
#    Unidade de Medida       Bandeira
# 0         R$ / litro  VIBRA ENERGIA
# 1         R$ / litro  VIBRA ENERGIA
# 2         R$ / litro  VIBRA ENERGIA
# 3         R$ / litro  VIBRA ENERGIA
# 4         R$ / litro  VIBRA ENERGIA
# 5         R$ / litro  VIBRA ENERGIA
# 6         R$ / litro  VIBRA ENERGIA
# 7         R$ / litro  VIBRA ENERGIA
# 8         R$ / litro  VIBRA ENERGIA
# 9         R$ / litro  VIBRA ENERGIA
# 10        R$ / litro         BRANCA
# 11        R$ / litro         BRANCA
# 12        R$ / litro         BRANCA
# 13        R$ / litro         BRANCA
# 14        R$ / litro         BRANCA

# %%
#Comandos dataframa.shape()
print(combustiveis_df.shape)

#só as linhas 
print(combustiveis_df.shape[0])
# Out:
# (168409, 16)
# 168409

# %%
#Quais são as colunas e que tipo de dados cada uma tem
print(combustiveis_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
#  15  Bandeira           168409 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(13)
# memory usage: 20.6+ MB
# None

# %%
#Describe () mostra estatística "mais básica"
print(combustiveis_df.describe())
# Out:
#        Valor de Venda  Valor de Compra
# count   168409.000000              0.0
# mean         6.005184              NaN
# std          0.794541              NaN
# min          2.849000              NaN
# 25%          5.339000              NaN
# 50%          5.859000              NaN
# 75%          6.699000              NaN
# max          8.990000              NaN

# %%
#filtrar apenas uma coluna
display(combustiveis_df["Revenda"])
# Out:
# 0                               POSTO ARAPIRACA LTDA
# 1                               POSTO ARAPIRACA LTDA
# 2                               POSTO ARAPIRACA LTDA
# 3                               POSTO ARAPIRACA LTDA
# 4                               POSTO ARAPIRACA LTDA
#                              ...
# 168404    COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168406             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168407             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168408             ABC DISTRIBUICAO DE PETROLEO LTDA
# Name: Revenda, Length: 168409, dtype: object

# %%
#Aqui iremos criar um novo dataframe apenas com as colunas que eu quero 

ca_df=combustiveis_df[['Revenda','Municipio','Produto','Valor de Venda']]
display(ca_df)
# Out:
#                                            Revenda  Municipio  \
# 0                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 1                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 2                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 3                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 4                             POSTO ARAPIRACA LTDA  ARAPIRACA
# ...                                            ...        ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA     JEQUIE
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
#
#                    Produto  Valor de Venda
# 0                 GASOLINA           6.799
# 1                   ETANOL           5.299
# 2                   DIESEL           5.549
# 3       GASOLINA ADITIVADA           6.899
# 4               DIESEL S10           5.649
# ...                    ...             ...
# 168404              ETANOL           5.859
# 168405            GASOLINA           6.580
# 168406              ETANOL           4.740
# 168407          DIESEL S10           5.448
# 168408  GASOLINA ADITIVADA           6.580
#
# [168409 rows x 4 columns]

# %%
#Exibe a quarta linha
display(ca_df.loc[168404])
# Out:
# Revenda           COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# Municipio                                             JEQUIE
# Produto                                               ETANOL
# Valor de Venda                                         5.859
# Name: 168404, dtype: object

# %%
#Exibir por intervalo da 10 linha até a 20
display(ca_df.loc[9:19])
# Out:
#                                   Revenda        Municipio  \
# 9          AUTO POSTO FREITAS & MAIA LTDA  DELMIRO GOUVEIA
# 10               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 11               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 12               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 13               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 14  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 15  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 16  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 17  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 18  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 19         MARCOS ANTONIO DA SILVA CABRAL      ITACOATIARA
#
#                Produto  Valor de Venda
# 9           DIESEL S10           5.983
# 10            GASOLINA           7.197
# 11              ETANOL           5.987
# 12              DIESEL           5.978
# 13          DIESEL S10           5.989
# 14            GASOLINA           7.175
# 15              ETANOL           5.930
# 16              DIESEL           5.955
# 17  GASOLINA ADITIVADA           7.175
# 18          DIESEL S10           5.980
# 19            GASOLINA           6.990

# %%
#Criar um dataframe gas_df 
#contendo apenas 4 colunas (Revenda, Municipio, Produto, Valor de Venda)
#somente com combustivel que contém gasolina
gas_df = ca_df.loc[ca_df['Produto'] == 'GASOLINA']
display(gas_df)

#Gasolina mais cara do país
display(gas_df.max())
# Out:
#                                                   Revenda  \
# 0                                    POSTO ARAPIRACA LTDA
# 5                          AUTO POSTO FREITAS & MAIA LTDA
# 10                               AUTO POSTO DA PEDRA LTDA
# 14                  COMERCIO DE COMBUSTIVEIS NENZITA LTDA
# 19                         MARCOS ANTONIO DA SILVA CABRAL
# ...                                                   ...
# 168392                           AUTO POSTO KM BAURU LTDA
# 168394      COOPERCITRUS COOPERATIVA DE PRODUTORES RURAIS
# 168399  VICMAR COMERCIO DE COMBUSTIVEIS E LUBRIFICANTE...
# 168403         COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405                  ABC DISTRIBUICAO DE PETROLEO LTDA
#
#                     Municipio   Produto  Valor de Venda
# 0                   ARAPIRACA  GASOLINA           6.799
# 5             DELMIRO GOUVEIA  GASOLINA           7.198
# 10            DELMIRO GOUVEIA  GASOLINA           7.197
# 14            DELMIRO GOUVEIA  GASOLINA           7.175
# 19                ITACOATIARA  GASOLINA           6.990
# ...                       ...       ...             ...
# 168392                  BAURU  GASOLINA           6.199
# 168394              ITUIUTABA  GASOLINA           6.899
# 168399  CAMPOS DOS GOYTACAZES  GASOLINA           7.090
# 168403                 JEQUIE  GASOLINA           6.799
# 168405              ITUIUTABA  GASOLINA           6.580
#
# [42209 rows x 4 columns]
# Revenda           ZV POSTO DE SERVIÇO LTDA.
# Municipio                           XANXERE
# Produto                            GASOLINA
# Valor de Venda                        7.999
# dtype: object

# %%
#Etanol de uma cidade e o seu valor 
etanol_indaiatuba_df=ca_df.loc[(ca_df['Produto']=='ETANOL')&(ca_df['Municipio'] =='INDAIATUBA')]
display(etanol_indaiatuba_df)
# Out:
#                                                   Revenda   Municipio Produto  \
# 12774            COMERCIAL DE COMBUSTIVEIS INDAIA US LTDA  INDAIATUBA  ETANOL
# 12778   HELVETIA COMERCIO DE COMBUSTIVEIS E SERVICOS LTDA  INDAIATUBA  ETANOL
# 12783             CENTRO AUTOMOTIVO RIVIERA TROPICAL LTDA  INDAIATUBA  ETANOL
# 12788                  AUTO POSTO JARDIM CALIFORNIA LTDA.  INDAIATUBA  ETANOL
# 12790       POSTO TREMENDAO LUBRIFICANTES E SERVIÇOS LTDA  INDAIATUBA  ETANOL
# ...                                                   ...         ...     ...
# 159497                M.LI COMERCIO DE COMBUSTIVEIS LTDA.  INDAIATUBA  ETANOL
# 160592                       AUTO POSTO NAMORADA II LTDA.  INDAIATUBA  ETANOL
# 160806                            POSTO RECREIO OURO LTDA  INDAIATUBA  ETANOL
# 160994                             POSTO DOS ESTEVES LTDA  INDAIATUBA  ETANOL
# 161798          ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA  INDAIATUBA  ETANOL
#
#         Valor de Venda
# 12774            5.447
# 12778            5.447
# 12783            5.079
# 12788            4.999
# 12790            5.199
# ...                ...
# 159497           4.699
# 160592           4.679
# 160806           4.999
# 160994           4.999
# 161798           4.899
#
# [143 rows x 4 columns]

# %%
# Média de preços dos combustiveis Gasolina e Gasolina Aditivada do Bairro Mooca em São Paulo
# display(combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') & (combustiveis_df['Municipio'] == 'SAO PAULO') & ((combustiveis_df['Produto'] =='GASOLINA') | (combustiveis_df['Produto'] == 'GASOLINA ADITIVADA'))])

display(combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') & 
(combustiveis_df['Municipio'] == 'SAO PAULO') & 
((combustiveis_df['Produto'] == 'GASOLINA') | (combustiveis_df['Produto'] == 'GASOLINA ADITIVADA')), ['Valor de Venda']].mean())
# Out:
# Valor de Venda    6.575596
# dtype: float64

# %%
# Como mostrar média de valor de venda POR COMBUSTÍVEL Brasil todo?
media_por_combustivel_df = ca_df[['Produto', 'Valor de Venda']].groupby(by='Produto').mean().round(2)
display(media_por_combustivel_df)
# Out:
#                     Valor de Venda
# Produto
# DIESEL                        5.38
# DIESEL S10                    5.45
# ETANOL                        5.46
# GASOLINA                      6.71
# GASOLINA ADITIVADA            6.86
# GNV                           4.39

# %%
# adicionar uma coluna de valor booleano no combustiveis_df
# chamada "Ativo" que, por padrão, vai ser True para todas as linhas
combustiveis_df['Ativo'] = True
print(combustiveis_df.info())
display(combustiveis_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
#  15  Bandeira           168409 non-null  object
#  16  Ativo              168409 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(2), object(13)
# memory usage: 20.7+ MB
# None
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira  Ativo
# 0              NaN        R$ / litro  VIBRA ENERGIA   True
# 1              NaN        R$ / litro  VIBRA ENERGIA   True
# 2              NaN        R$ / litro  VIBRA ENERGIA   True
# 3              NaN        R$ / litro  VIBRA ENERGIA   True
# 4              NaN        R$ / litro  VIBRA ENERGIA   True

# %%
# Exportar para Excel o dataframe com etanol em Indaiatuba....
etanol_indaiatuba_df.to_excel('etanol_indaiatuba.xlsx', sheet_name='Etanol em Indaiatuba', index=False)

# %%
combustiveis_df = pd.read_excel("ca-2021-02.xlsx")
display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira
# 0              NaN        R$ / litro  VIBRA ENERGIA
# 1              NaN        R$ / litro  VIBRA ENERGIA
# 2              NaN        R$ / litro  VIBRA ENERGIA
# 3              NaN        R$ / litro  VIBRA ENERGIA
# 4              NaN        R$ / litro  VIBRA ENERGIA

# %% [markdown]
# # Últimas etapas

# %%
import numpy as np

combustiveis_df['Status do Valor de Venda'] = np.where(combustiveis_df['Valor de Venda'] > 6.5, 'Caro', 'Barato')
display(combustiveis_df[['Revenda', 'Valor de Venda', 'Status do Valor de Venda']])
# Out:
#                                            Revenda  Valor de Venda  \
# 0                             POSTO ARAPIRACA LTDA           6.799
# 1                             POSTO ARAPIRACA LTDA           5.299
# 2                             POSTO ARAPIRACA LTDA           5.549
# 3                             POSTO ARAPIRACA LTDA           6.899
# 4                             POSTO ARAPIRACA LTDA           5.649
# ...                                            ...             ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA           5.859
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA           4.740
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA           5.448
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
#
#        Status do Valor de Venda
# 0                          Caro
# 1                        Barato
# 2                        Barato
# 3                          Caro
# 4                        Barato
# ...                         ...
# 168404                   Barato
# 168405                     Caro
# 168406                   Barato
# 168407                   Barato
# 168408                     Caro
#
# [168409 rows x 3 columns]

# %%
# Calcular postos de gasolina por habitante temos na amostragem de 
# combustiveis nov/2021

num_habitantes_df = pd.read_csv("ibge_num_habitantes_estimado.csv", sep=";")
num_habitantes_df.rename(columns={"Estado":"Estado - Sigla"}, inplace=True)
display(num_habitantes_df)
# Out:
#          Municipio Estado - Sigla  NumHabitantes2021
# 0   BELO HORIZONTE             MG            2530701
# 1         CAMPINAS             SP            1223237
# 2     CAMPO GRANDE             MS             916001
# 3         CURITIBA             PR            1963726
# 4          GOIANIA             GO            1555626
# 5       INDAIATUBA             SP             260690
# 6            NATAL             RN             803739
# 7           PALMAS             TO             313349
# 8        PENAPOLIS             SP              64098
# 9     PORTO ALEGRE             RS            1492530
# 10     PORTO VELHO             RO             548952
# 11      RIO BRANCO             AC             419452
# 12  RIO DE JANEIRO             RJ            6775561
# 13    SALTO GRANDE             SP               9396
# 14          SANTOS             SP             433991
# 15       SAO PAULO             SP           12396372
# 16     SAO VICENTE             SP             370839
# 17     SERRA NEGRA             SP              29669

# %%
#Fazer um MERGE dos dois dataframes
colunas = ['Municipio', 'Estado - Sigla']
merge_df = combustiveis_df.merge(num_habitantes_df, how="inner", on=colunas)
display(merge_df)
print(merge_df.info())
# Out:
#       Regiao - Sigla Estado - Sigla   Municipio  \
# 0                 CO             GO     GOIANIA
# 1                 CO             GO     GOIANIA
# 2                 CO             GO     GOIANIA
# 3                 CO             GO     GOIANIA
# 4                 CO             GO     GOIANIA
# ...              ...            ...         ...
# 20629             SE             SP  INDAIATUBA
# 20630             SE             SP  INDAIATUBA
# 20631             SE             SP  INDAIATUBA
# 20632             SE             SP  INDAIATUBA
# 20633             SE             SP  INDAIATUBA
#
#                                          Revenda      CNPJ da Revenda  \
# 0                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 1                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 2                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 3                              POSTO DO BOI LTDA   06.880.293/0001-25
# 4                              POSTO DO BOI LTDA   06.880.293/0001-25
# ...                                          ...                  ...
# 20629                     POSTO DOS ESTEVES LTDA   20.763.169/0001-00
# 20630  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
# 20631  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
# 20632  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
# 20633  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
#
#                           Nome da Rua Numero Rua  \
# 0      AVENIDA VEREADOR JOSE MONTEIRO       1854
# 1      AVENIDA VEREADOR JOSE MONTEIRO       1854
# 2      AVENIDA VEREADOR JOSE MONTEIRO       1854
# 3               AVENIDA INDEPENDENCIA      2.908
# 4               AVENIDA INDEPENDENCIA      2.908
# ...                               ...        ...
# 20629                 AVENIDA ITORORO        160
# 20630      AVENIDA PRESIDENTE KENNEDY        496
# 20631      AVENIDA PRESIDENTE KENNEDY        496
# 20632      AVENIDA PRESIDENTE KENNEDY        496
# 20633      AVENIDA PRESIDENTE KENNEDY        496
#
#                                Complemento                Bairro        Cep  \
# 0      QUADRA08                  LOTE  11E  SETOR NEGRAO DE LIMA  74650-300
# 1      QUADRA08                  LOTE  11E  SETOR NEGRAO DE LIMA  74650-300
# 2      QUADRA08                  LOTE  11E  SETOR NEGRAO DE LIMA  74650-300
# 3                                      NaN             VILA NOVA  74645-010
# 4                                      NaN             VILA NOVA  74645-010
# ...                                    ...                   ...        ...
# 20629                                  NaN                CENTRO  13330-055
# 20630                                  NaN         CIDADE NOVA I  13334-170
# 20631                                  NaN         CIDADE NOVA I  13334-170
# 20632                                  NaN         CIDADE NOVA I  13334-170
# 20633                                  NaN         CIDADE NOVA I  13334-170
#
#                   Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0                GASOLINA     2021-11-01           6.999              NaN
# 1                  ETANOL     2021-11-01           4.990              NaN
# 2      GASOLINA ADITIVADA     2021-11-01           7.130              NaN
# 3                GASOLINA     2021-11-01           6.990              NaN
# 4                  ETANOL     2021-11-01           4.990              NaN
# ...                   ...            ...             ...              ...
# 20629            GASOLINA     2021-12-28           6.499              NaN
# 20630          DIESEL S10     2021-12-28           5.499              NaN
# 20631  GASOLINA ADITIVADA     2021-12-28           6.699              NaN
# 20632              ETANOL     2021-12-28           4.899              NaN
# 20633            GASOLINA     2021-12-28           6.299              NaN
#
#       Unidade de Medida  Bandeira Status do Valor de Venda  NumHabitantes2021
# 0            R$ / litro    RAIZEN                     Caro            1555626
# 1            R$ / litro    RAIZEN                   Barato            1555626
# 2            R$ / litro    RAIZEN                     Caro            1555626
# 3            R$ / litro    BRANCA                     Caro            1555626
# 4            R$ / litro    BRANCA                   Barato            1555626
# ...                 ...       ...                      ...                ...
# 20629        R$ / litro  IPIRANGA                   Barato             260690
# 20630        R$ / litro    RAIZEN                   Barato             260690
# 20631        R$ / litro    RAIZEN                     Caro             260690
# 20632        R$ / litro    RAIZEN                   Barato             260690
# 20633        R$ / litro    RAIZEN                   Barato             260690
#
# [20634 rows x 18 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Regiao - Sigla            20634 non-null  object
#  1   Estado - Sigla            20634 non-null  object
#  2   Municipio                 20634 non-null  object
#  3   Revenda                   20634 non-null  object
#  4   CNPJ da Revenda           20634 non-null  object
#  5   Nome da Rua               20634 non-null  object
#  6   Numero Rua                20634 non-null  object
#  7   Complemento               3837 non-null   object
#  8   Bairro                    20634 non-null  object
#  9   Cep                       20634 non-null  object
#  10  Produto                   20634 non-null  object
#  11  Data da Coleta            20634 non-null  datetime64[ns]
#  12  Valor de Venda            20634 non-null  float64
#  13  Valor de Compra           0 non-null      float64
#  14  Unidade de Medida         20634 non-null  object
#  15  Bandeira                  20634 non-null  object
#  16  Status do Valor de Venda  20634 non-null  object
#  17  NumHabitantes2021         20634 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(14)
# memory usage: 3.0+ MB
# None

# %%
#Destruir coluna completamente vazia (todas as linhas são nulas)
merge_df.dropna(axis='columns', inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Regiao - Sigla            20634 non-null  object
#  1   Estado - Sigla            20634 non-null  object
#  2   Municipio                 20634 non-null  object
#  3   Revenda                   20634 non-null  object
#  4   CNPJ da Revenda           20634 non-null  object
#  5   Nome da Rua               20634 non-null  object
#  6   Numero Rua                20634 non-null  object
#  7   Bairro                    20634 non-null  object
#  8   Cep                       20634 non-null  object
#  9   Produto                   20634 non-null  object
#  10  Data da Coleta            20634 non-null  datetime64[ns]
#  11  Valor de Venda            20634 non-null  float64
#  12  Unidade de Medida         20634 non-null  object
#  13  Bandeira                  20634 non-null  object
#  14  Status do Valor de Venda  20634 non-null  object
#  15  NumHabitantes2021         20634 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(13)
# memory usage: 2.7+ MB
# None

# %%
#Agrupar e contar quantos postos tem na cidade.
postos_por_municipio_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()
postos_por_municipio_df.reset_index(inplace=True)
#display(postos_por_municipio_df.info())
postos_por_municipio_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_municipio_df.rename(columns={"Revenda": "NumPostos"}, inplace=True)

postos_por_municipio_df['NumHabitantesPorPosto'] = postos_por_municipio_df['NumHabitantes2021'] / postos_por_municipio_df['NumPostos']
#display(postos_por_municipio_df.info())
display(postos_por_municipio_df)
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  Regiao - Sigla  \
# 0              AC      RIO BRANCO             419452            1090
# 1              GO         GOIANIA            1555626            1667
# 2              MG  BELO HORIZONTE            2530701             827
# 3              MS    CAMPO GRANDE             916001            1606
# 4              PR        CURITIBA            1963726            1291
# 5              RJ  RIO DE JANEIRO            6775561            2445
# 6              RN           NATAL             803739            1093
# 7              RO     PORTO VELHO             548952             805
# 8              RS    PORTO ALEGRE            1492530            1142
# 9              SP        CAMPINAS            1223237            1605
# 10             SP      INDAIATUBA             260690             562
# 11             SP          SANTOS             433991             459
# 12             SP       SAO PAULO           12396372            5220
# 13             SP     SAO VICENTE             370839             453
# 14             TO          PALMAS             313349             369
#
#     NumPostos  Nome da Rua  Numero Rua  Bairro   Cep  Produto  Data da Coleta  \
# 0        1090         1090        1090    1090  1090     1090            1090
# 1        1667         1667        1667    1667  1667     1667            1667
# 2         827          827         827     827   827      827             827
# 3        1606         1606        1606    1606  1606     1606            1606
# 4        1291         1291        1291    1291  1291     1291            1291
# 5        2445         2445        2445    2445  2445     2445            2445
# 6        1093         1093        1093    1093  1093     1093            1093
# 7         805          805         805     805   805      805             805
# 8        1142         1142        1142    1142  1142     1142            1142
# 9        1605         1605        1605    1605  1605     1605            1605
# 10        562          562         562     562   562      562             562
# 11        459          459         459     459   459      459             459
# 12       5220         5220        5220    5220  5220     5220            5220
# 13        453          453         453     453   453      453             453
# 14        369          369         369     369   369      369             369
#
#     Valor de Venda  Unidade de Medida  Bandeira  Status do Valor de Venda  \
# 0             1090               1090      1090                      1090
# 1             1667               1667      1667                      1667
# 2              827                827       827                       827
# 3             1606               1606      1606                      1606
# 4             1291               1291      1291                      1291
# 5             2445               2445      2445                      2445
# 6             1093               1093      1093                      1093
# 7              805                805       805                       805
# 8             1142               1142      1142                      1142
# 9             1605               1605      1605                      1605
# 10             562                562       562                       562
# 11             459                459       459                       459
# 12            5220               5220      5220                      5220
# 13             453                453       453                       453
# 14             369                369       369                       369
#
#     NumHabitantesPorPosto
# 0              384.818349
# 1              933.188962
# 2             3060.097944
# 3              570.361768
# 4             1521.089078
# 5             2771.190593
# 6              735.351327
# 7              681.927950
# 8             1306.943958
# 9              762.141433
# 10             463.861210
# 11             945.514161
# 12            2374.783908
# 13             818.629139
# 14             849.184282

# %%
#Gráfico
import matplotlib.pyplot as plt

plt.hist(combustiveis_df['Valor de Venda'])
# Out:
# (array([2.8000e+01, 6.7200e+02, 2.6370e+03, 3.8035e+04, 4.5319e+04,
#         2.7049e+04, 4.1406e+04, 1.2733e+04, 4.8700e+02, 4.3000e+01]),
#  array([2.849 , 3.4631, 4.0772, 4.6913, 5.3054, 5.9195, 6.5336, 7.1477,
#         7.7618, 8.3759, 8.99  ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(combustiveis_df['Valor de Venda'])

#Inserindo título no gráfico
plt.title("Valor médio dos Combustiveis - Nov/2021")
# Out:
# Text(0.5, 1.0, 'Valor médio dos Combustiveis - Nov/2021')

# %%
plt.hist(combustiveis_df['Valor de Venda'])

#Inserindo título no gráfico
plt.title("Valor médio dos Combustiveis - Nov/2021")

#Inserir rótulos na horizontal (eixo x) e vertical (eixo y)
plt.xlabel('Preço (em reais)')
plt.ylabel('Quantidade de coletas')

#Plota 
plt.show()

# %%
plt.hist(combustiveis_df['Valor de Venda'])

#Inserindo título no gráfico
plt.title("Valor médio dos Combustiveis - Nov/2021")

#Inserir rótulos na horizontal (eixo x) e vertical (eixo y)
plt.xlabel('Preço (em reais)')
plt.ylabel('Quantidade de coletas')

#Traça a linha vermelha tracejada com o preço médio
plt.axvline(combustiveis_df['Valor de Venda'].mean(), color='red', linestyle='dashed', linewidth=5)

#Plota 
plt.show()

# %%
#Visualização do consumo médio
c_mean = combustiveis_df['Valor de Venda'].groupby(by=combustiveis_df['Produto']).mean()
display(c_mean)
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
#gráfico
plt.figure(figsize=(7,5))

#Plotar o gráfico
c_mean.plot(
    kind="barh",
    xlabel="Tipo de Combustível",
    ylabel="Preço reais/litro",
    title='Média de preços por combustivel',
    color="red",
    alpha=0.6)

#Grid
plt.grid()


#Exibe
plt.show()

# %%
display(c_mean)

excel = 'por_litro.xlsx'
c_mean.to_excel(excel, 'Sumário')
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
# Personalizar a planilha Excel...
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Color, Alignment

# Abrir o Excel no openpyxl
wb = load_workbook(excel) # wb = Workbook

#Pegar a planilha certa... usando o Sheet Name (nome da planilha)
ws = wb['Sumário'] # Work Sheet (planilha atual, ativa, de trabalho)

#Vamos pintar o cabeçalho da tabela de "cinzinha"
cinzinha = PatternFill("solid", fgColor="808080")
coords = ['A1', 'B1']
for coord in coords:
  ws[coord].fill = cinzinha

#Salvar o Excel
wb.save(excel)

# %%
# Personalizar a planilha Excel...
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Color, Alignment

# Abrir o Excel no openpyxl
wb = load_workbook(excel) # wb = Workbook

#Pegar a planilha certa... usando o Sheet Name (nome da planilha)
ws = wb['Sumário'] # Work Sheet (planilha atual, ativa, de trabalho)

#Vamos pintar o cabeçalho da tabela de "cinzinha"
cinzinha = PatternFill("solid", fgColor="CCCCCC")
coords = ['A1', 'B1']
for coord in coords:
  ws[coord].fill = cinzinha

#Onde o preço do combustível for maior ou igual a 6,5 reais (6.5) pinta a fonte
#de vermelho e deixa negrito...
MAX_ROW = ws.max_row
num_linha = 2
while (num_linha <= MAX_ROW):
  coord = 'B'+str(num_linha) #coord="B{0}".format(num_linha)
  if ws[coord].value >= 6.5:
    ws[coord].font = Font(bold=True, color="FF0000")
  num_linha = num_linha + 1
#Salvar o Excel
wb.save(excel)
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Color, Alignment

#Vai abrir o Excel no openpyxl
wb = load_workbook(excel) # wb = Workbook

#Pegar a planilha certa... usando o Sheet Name (nome da planilha)
ws = wb['Sumário'] # Work Sheet -> planilha atual, ativa, de trabalho

#Vamos pintar o cabeçalho da tabela de "cinzinha"
cinzinha = PatternFill("solid", fgColor="CCCCCC")
coords = ['A1', 'B1']
for coord in coords:
  ws[coord].fill = cinzinha

#Onde o preço do combustível for maior ou igual a 6,5 reais (6.5) pinta a fonte
#de vermelho e deixa negrito...
MAX_ROW = ws.max_row
num_linha = 2
while (num_linha <= MAX_ROW):
  coord = 'B'+str(num_linha) #coord="B{0}".format(num_linha)
  if ws[coord].value >= 6.5:
    ws[coord].font = Font(bold=True, color="FF0000")
  num_linha = num_linha + 1
#Salvar o Excel
wb.save(excel)
